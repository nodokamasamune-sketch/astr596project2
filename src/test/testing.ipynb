# %%
import numpy as np
import matplotlib.pyplot as plt

from plotting_10 import random_n_plotting
from plotting_3d import jupiter_plotting
from plotting_2d import earth_sun_plotter
from nbody_plotting import nbody_plotting
from IMF_plummer_validation import IMF_validation, plummer_validation
from cluster_evolution import cluster_evolution_plotter
from animation_plotting import cluster_artificial
# Out:
# Traceback (most recent call last):
#
#   File ~/miniforge3/envs/astr596/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[6], line 10
#     from animation_plotting import cluster_artificial
#
#   File ~/astr596/projects/project2/astr-596-project-02-nodokamasamune-sketch/test/animation_plotting.py:119
#     import sys
#               ^
# IndentationError: unindent does not match any outer indentation level

# %%
random_n_plotting()

# %%
jupiter_plotting(3, 24, 0.01)

# %%
earth_sun_plotter()

# %%
nbody_plotting(10, 100, 0.1)
# Out:
# 1.0

# %%
IMF_validation()
# Out:
# 1.0

# %%
plummer_validation()
# Out:
# 1.0

# %%
cluster_evolution_plotter(10, 100, 0.1)
# Out:
# 1.0

# %%
cluster_animation(100, 100, 0.1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 cluster_animation(100, 100, 0.1)
#
# NameError: name 'cluster_animation' is not defined

# %%
cluster_artificial(10, 100, 0.1)
